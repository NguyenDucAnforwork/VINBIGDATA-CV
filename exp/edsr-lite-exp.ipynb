# %%
# %run /kaggle/input/fire-sr/pytorch/default/1/main.py \
    loader.hr_dir=/kaggle/input/d/haiaunho/fire-sr/dataset/hr \
    loader.lr_dir=/kaggle/input/d/haiaunho/fire-sr/dataset/lr \
    model=edsr_lite trainer.epochs=50
# Out:
# [1] Data successfully loaded.
# Train: 685 | Val: 85 | Test: 85
# [2] Model successfully built.
# Model: EDSRLite | #Params: 889795
# [3] Evaluator successfully built.
# [001] L1=0.2673 | Val PSNR=12.226 SSIM=0.4919 | lr=9.99e-05 | 8.9s
# [002] L1=0.0819 | Val PSNR=21.844 SSIM=0.7146 | lr=9.96e-05 | 8.8s
# [003] L1=0.0483 | Val PSNR=22.835 SSIM=0.7510 | lr=9.91e-05 | 8.9s
# [004] L1=0.0440 | Val PSNR=23.687 SSIM=0.7827 | lr=9.84e-05 | 8.9s
# [005] L1=0.0425 | Val PSNR=24.254 SSIM=0.8028 | lr=9.76e-05 | 8.9s
# [006] L1=0.0411 | Val PSNR=24.750 SSIM=0.8157 | lr=9.65e-05 | 8.8s
# [007] L1=0.0399 | Val PSNR=25.257 SSIM=0.8268 | lr=9.52e-05 | 8.8s
# [008] L1=0.0390 | Val PSNR=25.687 SSIM=0.8373 | lr=9.38e-05 | 8.9s
# [009] L1=0.0370 | Val PSNR=26.097 SSIM=0.8478 | lr=9.22e-05 | 9.0s
# [010] L1=0.0363 | Val PSNR=26.282 SSIM=0.8546 | lr=9.05e-05 | 8.9s
# [011] L1=0.0355 | Val PSNR=26.465 SSIM=0.8586 | lr=8.85e-05 | 8.9s
# [012] L1=0.0350 | Val PSNR=26.580 SSIM=0.8621 | lr=8.64e-05 | 8.9s
# ...
